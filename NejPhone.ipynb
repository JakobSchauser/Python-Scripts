# %%
import matplotlib.pyplot as plt

plt.xkcd()
plt.scatter(0.5,0.5,50,label = "iPhone")
plt.legend()
plt.xlim((0,1))
plt.ylim((0,1))

plt.xlabel("Nej")
plt.ylabel("Ja")
# plt.title("nejPhone")
# Out:
# Text(0, 0.5, 'Ja')
