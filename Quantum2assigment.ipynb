# %%
import numpy as np
import matplotlib.pyplot as plt

% matplotlib notebook

Ep = lambda d1,d2,g: ((d1+d2)+np.sqrt((d1+d2)**2-4*d1*d2+4*g**2))/2
Em = lambda d1,d2,g: ((d1+d2)-np.sqrt((d1+d2)**2-4*d1*d2+4*g**2))/2

d2s = np.linspace(0,2,200)

plt.figure()
plt.plot(d2s,Ep(1,d2s,0),label="g = 0, Positive")
plt.plot(d2s,Em(1,d2s,0),label="g = 0, Negative")
plt.plot(d2s,Ep(1,d2s,0.1),label="g = 0.1, Positive")
plt.plot(d2s,Em(1,d2s,0.1),label="g = 0.1, Negative")
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pertubated = lambda d1,d2,g: g**2/(d2-d1)
plt.figure()
#d2s.remove(0)
y = pertubated(1,d2s,0.1)
y[d2s==0]
plt.plot(d2s,-y+1,label="pertubated, Positive",ls='--')
plt.plot(d2s,y+d2s,label="pertubated, Negative",ls='--')
plt.plot(d2s,Ep(1,d2s,0.1),label="g = 0.1, Positive")
plt.plot(d2s,Em(1,d2s,0.1),label="g = 0.1, Negative")
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Out:
# array([0.        , 0.01005025, 0.0201005 , 0.03015075, 0.04020101,
#        0.05025126, 0.06030151, 0.07035176, 0.08040201, 0.09045226,
#        0.10050251, 0.11055276, 0.12060302, 0.13065327, 0.14070352,
#        0.15075377, 0.16080402, 0.17085427, 0.18090452, 0.19095477,
#        0.20100503, 0.21105528, 0.22110553, 0.23115578, 0.24120603,
#        0.25125628, 0.26130653, 0.27135678, 0.28140704, 0.29145729,
#        0.30150754, 0.31155779, 0.32160804, 0.33165829, 0.34170854,
#        0.35175879, 0.36180905, 0.3718593 , 0.38190955, 0.3919598 ,
#        0.40201005, 0.4120603 , 0.42211055, 0.4321608 , 0.44221106,
#        0.45226131, 0.46231156, 0.47236181, 0.48241206, 0.49246231,
#        0.50251256, 0.51256281, 0.52261307, 0.53266332, 0.54271357,
#        0.55276382, 0.56281407, 0.57286432, 0.58291457, 0.59296482,
#        0.60301508, 0.61306533, 0.62311558, 0.63316583, 0.64321608,
#        0.65326633, 0.66331658, 0.67336683, 0.68341709, 0.69346734,
# ...

# %%
plt.figure()
xr = np.linspace(3/4,5/4,100)
plt.plot(xr,2-(xr)**2)
plt.plot(xr,np.ones(len(xr)))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
xr = np.linspace(3/4,5/4,100)
plt.plot(xr,2-(xr)**2)
plt.plot(xr,np.ones(len(xr)))
plt.plot(xr,np.ones(len(xr))-(10/(3-xr**2))+1/(1-xr**2))
plt.plot(xr,2-(xr)**2+(10/(3-xr**2))+1/(xr**2-1))
plt.ylim(-2,4)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-2, 4)
