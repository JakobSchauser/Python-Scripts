# %%
import numpy as np
n = 2000
d1 = np.random.randint(1,21,n)
d2 = np.random.randint(1,21,n)

tf = d1[d1>10]

# %%
tf
# Out:
# array([14, 16, 18, 15, 13, 13, 17, 12, 19, 11, 19, 14, 19, 17, 12, 20, 12,
#        17, 13, 13, 18, 18, 18, 15, 14, 17, 13, 19, 18, 11, 13, 11, 12, 14,
#        14, 15, 14, 17, 15, 15, 17, 12, 16, 14, 11, 19, 17, 16, 14, 15, 11,
#        17, 20, 19, 17, 11, 11, 12, 13, 13, 14, 11, 15, 16, 12, 12, 12, 20,
#        15, 11, 19, 19, 11, 17, 20, 15, 14, 11, 13, 13, 18, 12, 20, 18, 16,
#        15, 18, 19, 19, 20, 15, 17, 12, 11, 14, 19, 15, 19, 13, 18, 19, 15,
#        17, 12, 18, 12, 20, 18, 12, 17, 12, 11, 12, 17, 15, 19, 19, 18, 15,
#        18, 20, 17, 11, 14, 13, 15, 14, 12, 17, 14, 12, 19, 19, 15, 19, 19,
#        19, 13, 20, 11, 14, 18, 18, 20, 20, 11, 11, 15, 12, 12, 19, 12, 18,
#        12, 17, 19, 19, 16, 20, 15, 12, 16, 15, 20, 20, 20, 12, 12, 11, 15,
#        19, 13, 18, 13, 17, 13, 11, 17, 20, 11, 19, 17, 11, 16, 19, 15, 19,
#        14, 15, 16, 17, 15, 20, 13, 19, 14, 19, 17, 20, 20, 12, 14, 15, 18,
# ...
