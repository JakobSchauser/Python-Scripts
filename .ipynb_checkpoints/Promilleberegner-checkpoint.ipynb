# %%
import numpy as np
import matplotlib.pyplot as plt
import time

gender = "m"
weight = 75

burn = lambda weight: weight/10*time

curr_g = 0

def g2p(g):
    if(gender=="m"):
        return g/(weight*0.55)
    else:
        return g/(weight*0.68)
    

def add_genstand():
    curr_g+=12
    
def update():
    curr_g -= burn(weight)
