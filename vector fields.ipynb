# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x,y = np.meshgrid(np.linspace(-5,5,10),np.linspace(-5,5,10))

x,y = np.meshgrid(np.linspace(-5,5,10),np.linspace(-5,5,10))

u = (12*x/(x+1)-2*x**2)*y
v = y

plt.quiver(x,y,u,v)
plt.show()
